# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
pip install scikit-learn --upgrade --user
# Out:
# Requirement already up-to-date: scikit-learn in e:\anaconda\lib\site-packages (0.22.2.post1)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Evaluating the test scores.

# %%
# 5 random artists, graphs of size 100, with tag edges, pagerank as the eval metric

scores1 =[ 4, 9, 5, 5, 5, 7, 5, 4, 5, 4, 2, 3, 2, 3, 8, 2, 4, 6, 8,
4, 5, 6, 6, 8, 5, 5, 5, 6, 7, 7, 6, 3, 5,
2, 7, 5, 3, 2, 9, 4, 3, 6, 3, 5, 7, 8, 4, 9]

# each score in the list is the count of top artists in the graph that are also in the playlist.
# dividing the count by the number of unique artists

#print(len(scores1))
scores1 = [round((i / 73)*100, 3) for i in scores1]

sns.countplot(scores1)
plt.xlabel("% Correct")
plt.title('All Classic Hits, Top N by pagerank - 5 artists, nodes = 100, WITH tag-edges')
plt.show()

# %%
# 5 random artists, graphs of size 100, without tag edges

pagerank = [4, 5, 5, 3, 6, 3, 2, 3, 4, 3, 3, 3, 4, 3, 3, 3, 5, 5, 4, 5, 4, 2, 5, 7, 4, 4, 5, 2, 3, 6
,6, 2, 3, 4, 2, 2, 5, 4, 2, 5, 3, 3, 3, 4, 2, 5, 4, 3]
pagerank = [round((i / 73)*100, 3) for i in pagerank]

degcent = [3, 2, 3, 3, 6, 2, 2, 2, 4, 1, 2, 1, 4, 3, 2, 4, 5, 4, 5, 4, 3, 2, 5, 7, 4, 3, 3, 1, 2, 6
,3, 1, 1, 4, 2, 2, 4, 2, 0, 4, 5, 2, 2, 2, 1, 5, 3, 3]
degcent = [round((i / 73)*100, 3) for i in degcent]

evcent = [4, 1, 4, 3, 4, 2, 1, 1, 2, 1, 1, 1, 1, 6, 1, 4, 5, 5, 1, 4, 1, 1, 4, 4, 1, 1, 1, 1, 3, 4
,1, 2, 0, 3, 1, 1, 4, 1, 1, 2, 2, 0, 1, 2, 1, 4, 3, 1]
evcent = [round((i / 73)*100, 3) for i in evcent]

harmcent =[5, 2, 5, 5, 5, 1, 3, 3, 3, 2, 4, 2, 2, 5, 3, 4, 4, 7, 4, 4, 4, 2, 4, 7, 4, 3, 5, 1, 3, 5
,3, 3, 2, 3, 1, 2, 4, 3, 1, 2, 4, 2, 0, 4, 1, 4, 5, 3]
harmcent = [round((i / 73)*100, 3) for i in harmcent]

meancent = [5, 2, 5, 5, 5, 1, 3, 3, 3, 2, 4, 2, 2, 5, 3, 5, 5, 7, 4, 4, 4, 2, 4, 7, 4, 3, 5, 1, 3, 5
,3, 3, 2, 3, 1, 2, 4, 3, 1, 2, 4, 2, 0, 4, 1, 4, 5, 3]
meancent = [round((i / 73)*100, 3) for i in meancent]

page = list(zip((['pagerank']*48), pagerank))
deg = list(zip((['degcent'] *48), degcent))
ev = list(zip((['evcent']*48),evcent))
harm = list(zip((['harmcent']*48),harmcent))
mean = list(zip((['mencent']*48),meancent))

llist = page+deg+ev+harm+mean

df = pd.DataFrame(llist, columns = ['metric', 'acc%'])
df

sns.catplot(x = 'metric', y = 'acc%',kind = 'box', data = df)
plt.title('All Classic Hits, Top N by metric - 5 artists, nodes = 100, WITHOUT tag-edges')
plt.show()

# %%
# 10 random artists, graphs of size 100, with tag edges

pagerank = [6, 5, 3, 3, 6, 8, 5, 7, 4, 10, 4, 7, 6, 5, 6, 5, 6, 3, 3, 7, 3,
4, 6, 7, 5, 5, 5, 6, 4, 8, 8, 6, 5, 7, 4, 5, 5, 6, 7, 7, 4, 5,
6, 4, 6, 3, 5, 4, 7, 5, 7, 5, 7, 6, 5, 8, 4, 4, 5, 5, 6, 5, 8]
pagerank = [round((i / 73)*100, 3) for i in pagerank]

degcent = [5, 4, 2, 2, 6, 8, 3, 4, 1, 4, 4, 6, 2, 3, 4, 3, 4, 1, 1, 3, 2,
1, 4, 5, 3, 4, 2, 4, 3, 5, 5, 5, 3, 5, 2, 4, 5, 5, 4, 5, 2, 2,
5, 2, 3, 3, 4, 2, 6, 5, 5, 4, 4, 4, 3, 5, 5, 4, 3, 3, 5, 3, 6]
degcent = [round((i / 73)*100, 3) for i in degcent]

evcent = [3, 1, 1, 1, 5, 5, 3, 3, 1, 5, 4, 2, 1, 4, 4, 1, 5, 2, 3, 1, 5,
1, 4, 4, 2, 4, 1, 1, 1, 6, 1, 1, 5, 5, 1, 1, 4, 2, 4, 4, 1, 1,
5, 1, 2, 1, 2, 1, 4, 2, 5, 1, 1, 3, 4, 6, 5, 6, 1, 1, 4, 1, 4]
evcent = [round((i / 73)*100, 3) for i in evcent]

harmcent =[5, 5, 2, 3, 6, 7, 4, 5, 4, 6, 4, 5, 4, 3, 4, 4, 8, 4, 2, 4, 4,
1, 6, 6, 2, 4, 2, 6, 2, 6, 6, 5, 5, 7, 5, 5, 5, 7, 6, 5, 2, 6,
6, 4, 4, 4, 3, 6, 5, 6, 6, 7, 5, 3, 5, 6, 8, 8, 5, 3, 6, 5, 5]
harmcent = [round((i / 73)*100, 3) for i in harmcent]

meancent = [5, 5, 2, 3, 6, 7, 4, 5, 4, 6, 4, 5, 4, 3, 4, 4, 9, 4, 2, 4, 4,
1, 6, 6, 2, 4, 2, 6, 2, 6, 6, 5, 5, 7, 5, 5, 5, 7, 6, 5, 2, 5,
6, 4, 4, 4, 3, 6, 5, 6, 6, 7, 5, 3, 5, 6, 8, 8, 5, 3, 6, 5, 5]
meancent = [round((i / 73)*100, 3) for i in meancent]

page = list(zip((['pagerank']*63), pagerank))
deg = list(zip((['degcent'] *63), degcent))
ev = list(zip((['evcent']*63),evcent))
harm = list(zip((['harmcent']*63),harmcent))
mean = list(zip((['mencent']*63),meancent))

llist = page+deg+ev+harm+mean

df = pd.DataFrame(llist, columns = ['metric', 'acc%'])
df

sns.catplot(x = 'metric', y = 'acc%',kind = 'box', data = df)
plt.title('All Classic Hits, Top N by metric - 10 artists, nodes = 100, WITH tag-edges')
plt.show()

# %%
# 10 random artists, graphs of size 150, with tag edges

pagerank = [6, 7, 10, 7, 9, 6, 6, 4, 7, 4, 4, 5, 7, 7, 6, 6, 6, 5, 3, 7, 7,
5, 5, 5, 5, 5, 5, 8, 5, 7, 4, 5, 6, 2, 7, 6, 4, 6, 4, 5, 4, 8]
pagerank = [round((i / 73)*100, 3) for i in pagerank]

degcent = [3, 4, 6, 4, 5, 4, 5, 3, 3, 2, 1, 3, 4, 3, 2, 4, 6, 4, 2, 3, 5,
4, 3, 3, 5, 5, 4, 4, 4, 6, 4, 4, 4, 0, 6, 4, 4, 5, 2, 5, 3, 6]
degcent = [round((i / 73)*100, 3) for i in degcent]

evcent = [1, 3, 4, 1, 3, 6, 1, 5, 2, 0, 0, 3, 1, 4, 3, 2, 5, 5, 1, 2, 4,
5, 3, 1, 1, 1, 5, 0, 4, 5, 4, 4, 6, 0, 5, 4, 4, 5, 2, 5, 2, 6]
evcent = [round((i / 73)*100, 3) for i in evcent]

harmcent =[3, 6, 5, 8, 6, 5, 4, 6, 4, 3, 2, 6, 3, 5, 4, 3, 4, 5, 2, 2, 6,
5, 5, 5, 7, 7, 4, 5, 5, 5, 3, 5, 5, 1, 5, 5, 7, 5, 4, 6, 4, 7]
harmcent = [round((i / 73)*100, 3) for i in harmcent]

meancent = [3, 6, 5, 8, 6, 5, 4, 6, 4, 3, 2, 6, 3, 5, 4, 3, 4, 5, 2, 2, 6,
5, 5, 5, 7, 7, 4, 5, 5, 5, 3, 5, 5, 1, 5, 5, 7, 5, 4, 6, 4, 7]
meancent = [round((i / 73)*100, 3) for i in meancent]

page = list(zip((['pagerank']*42), pagerank))
deg = list(zip((['degcent'] *42), degcent))
ev = list(zip((['evcent']*42),evcent))
harm = list(zip((['harmcent']*42),harmcent))
mean = list(zip((['mencent']*42),meancent))

llist = page+deg+ev+harm+mean

df = pd.DataFrame(llist, columns = ['metric', 'acc%'])
df

sns.catplot(x = 'metric', y = 'acc%',kind = 'box', data = df)
plt.title('All Classic Hits, Top N by metric - 10 artists, nodes = 150, WITH tag-edges')
plt.show()

# %% [markdown]
# ### Rock Classics Playlist
# There are 53 unique artists in this playlist

# %%
# 10 random artists, graphs of size 150, with tag edges

pagerank = [15, 13, 15, 15, 14, 16, 15, 12, 13, 14, 14, 14, 13, 18, 14, 17, 13, 14, 17, 12]
[14, 15, 14, 14, 15, 14, 13, 12, 17, 15, 16, 14, 14, 15, 15, 14, 16, 13, 15, 14]
pagerank = [round((i /53)*100, 3) for i in pagerank]

degcent = [14, 11, 13, 12, 12, 13, 12, 9, 10, 11, 11, 11, 13, 12, 11, 11, 9, 12, 13, 12]
[12, 13, 11, 10, 11, 9, 12, 11, 13, 11, 12, 11, 12, 11, 11, 12, 11, 9, 12, 13]
degcent = [round((i /53)*100, 3) for i in degcent]

evcent = [2, 10, 7, 9, 2, 6, 8, 2, 5, 2, 8, 1, 10, 2, 2, 2, 2, 8, 2, 6]
[8, 9, 2, 7, 3, 2, 8, 8, 7, 9, 8, 10, 2, 10, 2, 9, 5, 2, 7, 11]
evcent = [round((i /53)*100, 3) for i in evcent]

harmcent =[15, 14, 12, 12, 14, 12, 10, 13, 11, 14, 11, 13, 10, 13, 13, 12, 15, 14, 15, 14]
[13, 12, 14, 10, 10, 12, 14, 9, 15, 11, 13, 10, 15, 14, 13, 15, 13, 15, 10, 15]
harmcent = [round((i /53)*100, 3) for i in harmcent]

meancent = [15, 14, 12, 12, 14, 12, 10, 13, 10, 14, 11, 13, 10, 13, 13, 12, 15, 14, 15, 14]
[13, 12, 14, 10, 10, 12, 14, 9, 15, 11, 13, 10, 15, 14, 13, 15, 13, 15, 10, 15]
meancent = [round((i /53)*100, 3) for i in meancent]

page = list(zip((['pagerank']*20), pagerank))
deg = list(zip((['degcent'] *20), degcent))
ev = list(zip((['evcent']*20),evcent))
harm = list(zip((['harmcent']*20),harmcent))
mean = list(zip((['mencent']*20),meancent))

llist = page+deg+ev+harm+mean

df = pd.DataFrame(llist, columns = ['metric', 'acc%'])
df

sns.catplot(x = 'metric', y = 'acc%',kind = 'box', data = df)
plt.title('Rock Classics, Top N by metric - 10 artists, nodes = 150, WITH tag-edges')
plt.show()
